// %%
#r "C:/src/fsharp_tests/MyProvider2/src/MyProvider2.Runtime/bin/Debug/netstandard2.0/MyProvider2.Runtime.dll"
// Out:
// <div>
//     <div id='dotnet-interactive-this-cell-35648.Microsoft.DotNet.Interactive.Http.HttpPort' style='display: none'>
//         The below script needs to be able to find the current output cell; this is an easy method to get it.
//     </div>
//     <script type='text/javascript'>
// async function probeAddresses(probingAddresses) {
//     function timeout(ms, promise) {
//         return new Promise(function (resolve, reject) {
//             setTimeout(function () {
//                 reject(new Error('timeout'))
//             }, ms)
//             promise.then(resolve, reject)
//         })
//     }
//
//     if (Array.isArray(probingAddresses)) {
//         for (let i = 0; i < probingAddresses.length; i++) {
//
//             let rootUrl = probingAddresses[i];
//
//             if (!rootUrl.endsWith('/')) {
//                 rootUrl = `${rootUrl}/`;
//             }
//
//             try {
// ...

// %%
open MyProvider2

[<Literal>]
let BEGIN_STATE = "1; 2; 2; 1; 3; 4; 4; 3; 3; 4; 4; 3; 2; 4; 4; 2"

[<Literal>]
let END_STATE = "4; 3; 4; 2; 3; 1; 2; 4; 4; 2; 4; 3; 2; 4; 3; 1"

type RateType = MyProvider2.RateProvider<beginState, endState>
printfn $"{RateType().Property}"
// Out:
// generated binary is at 'C:\Users\sanya\AppData\Local\Temp\tmp4eiblt.dll'
// MoveLeft 0
// MoveRight 2
// MoveUp 3
// MoveDown 1
// MoveLeft 0
// MoveLeft 2
// MoveDown 1
// MoveUp 2
